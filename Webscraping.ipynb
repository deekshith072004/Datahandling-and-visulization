# %% [markdown]
# <a href="https://colab.research.google.com/github/MADHU-55/Data-handling-and-visualization/blob/main/Webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
link="https://www.popularmechanics.com/cars/g93/the-100-hottest-cars-of-all-time/"
link_text=requests.get(link).text
print(link_text)
# Out:
# <!DOCTYPE html><html lang="en-US"><head><meta charset="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0"/><link rel="canonical" href="https://www.popularmechanics.com/cars/g93/the-100-hottest-cars-of-all-time/"/><meta name="X-UA-Compatible" http-equiv="X-UA-Compatible" content="IE=edge,chrom=1"/><meta name="msapplication-tap-highlight" content="no"/><title>The Hottest Cars of All Time | List of the Coolest Cars </title><meta name="title" content="The Hottest Cars of All Time | List of the Coolest Cars "/><meta name="description" content="We delved deep into a huge range of automobiles to find the coolest cars of all time. These are the most beautiful classic and modern cars ever made."/><meta name="keywords" content="classic cars, best cars of all time, cool cars, coolest cars of all time, coolest cars ever, best cars ever, best classic cars, coolest cars, cool classic cars"/><meta property="og:type" content="website"/><meta name="theme-color" content="#00
# ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(link_text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.popularmechanics.com/cars/g93/the-100-hottest-cars-of-all-time/" rel="canonical"/>
#   <meta content="IE=edge,chrom=1" http-equiv="X-UA-Compatible" name="X-UA-Compatible"/>
#   <meta content="no" name="msapplication-tap-highlight"/>
#   <title>
#    The Hottest Cars of All Time | List of the Coolest Cars
#   </title>
#   <meta content="The Hottest Cars of All Time | List of the Coolest Cars " name="title"/>
#   <meta content="We delved deep into a huge range of automobiles to find the coolest cars of all time. These are the most beautiful classic and modern cars ever made." name="description"/>
#   <meta content="classic cars, best cars of all time, cool cars, coolest cars of all time, coolest cars ever, best cars ever, best classic cars, coolest cars, cool classic cars" name="keywords"/>
# ...

# %%
print(soup.title)
# Out:
# <title>The Hottest Cars of All Time | List of the Coolest Cars </title>

# %%
print(soup.title.string)
# Out:
# The Hottest Cars of All Time | List of the Coolest Cars

# %%
soup.a
# Out:
# <a class="css-1kkonqv e1c1bym14" href="/search/"><style data-emotion="css 13htjwu">.css-13htjwu{width:1rem;height:1rem;}</style><img alt="Search" class="css-13htjwu eqt11jm0" decoding="async" height="16" loading="lazy" src="/_assets/design-tokens/fre/static/icons/search.f1c199c.svg" title="Search" width="16"/><style data-emotion="css jk5e33">.css-jk5e33{padding:1rem;color:#000000;font-family:FreightSansW01,FreightSansW01-roboto,FreightSansW01-local,Helvetica,Arial,Sans-serif;font-size:0.875rem;line-height:2rem;}</style><span class="css-jk5e33 eqt11jm15">Search</span></a>

# %%
soup.find_all('a')
# Out:
# [<a class="css-1kkonqv e1c1bym14" href="/search/"><style data-emotion="css 13htjwu">.css-13htjwu{width:1rem;height:1rem;}</style><img alt="Search" class="css-13htjwu eqt11jm0" decoding="async" height="16" loading="lazy" src="/_assets/design-tokens/fre/static/icons/search.f1c199c.svg" title="Search" width="16"/><style data-emotion="css jk5e33">.css-jk5e33{padding:1rem;color:#000000;font-family:FreightSansW01,FreightSansW01-roboto,FreightSansW01-local,Helvetica,Arial,Sans-serif;font-size:0.875rem;line-height:2rem;}</style><span class="css-jk5e33 eqt11jm15">Search</span></a>,
#  <a class="css-cv3h5u e1c1bym14" href="#follow">Follow</a>,
#  <a class="css-cv3h5u e1c1bym14" href="https://shop.popularmechanics.com/popular-mechanics-all-access-2.html?cds_tracking_code=poppanelnav">Subscribe</a>,
#  <a class="css-cv3h5u e1c1bym14" href="https://www.popularmechanics.com/my-stuff/">My Bookmarks</a>,
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

htmldata = urlopen('https://www.popularmechanics.com/cars/g93/the-100-hottest-cars-of-all-time/')
soup = BeautifulSoup(htmldata, 'html.parser')
images = soup.find_all('img')

for item in images:
    print(item['src'])
# Out:
# /_assets/design-tokens/fre/static/icons/search.f1c199c.svg
# /_assets/design-tokens/fre/static/icons/close.38e3324.svg?primary=%2523595959
# /_assets/design-tokens/popularmechanics/static/images/logos/logo.a957255.svg?primary=%25231c6a65
# /_assets/design-tokens/fre/static/icons/search.f1c199c.svg?primary=%25231c6a65
# /_assets/design-tokens/fre/static/icons/saved.ad81f1a.svg?primary=%2523ffffff
# https://hips.hearstapps.com/hmg-prod/images/collest-cars-1653427349.png?crop=0.503xw:1.00xh;0.250xw,0&resize=640:*
# /_assets/design-tokens/fre/static/icons/social/pinterest.e8cf655.svg?primary=%2523ffffff
# https://hips.hearstapps.com/hmg-prod/images/carbon-fiber-shelby-mustang-1600685276.jpg?crop=0.9988636363636364xw:1xh;center,top&resize=980:*
# https://hips.hearstapps.com/hmg-prod/images/at-the-paris-festival-automobile-international-with-concept-news-photo-1600690007.jpg?crop=0.99902xw:1xh;center,top&resize=980:*
# ...
