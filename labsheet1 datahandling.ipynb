# %%
import pandas as pd
path="/content/business-financial-data-september-2023-quarter.zip"
df=pd.read_csv(path)
print(df.head(5))
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# 4  Business Data Collection - BDC
#
#                                              Group            Series_title_1  \
# 0  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 1  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 2  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 3  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 4  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
#
#          Series_title_2  Series_title_3 Series_title_4  Series_title_5
# 0  Forestry and Logging  Current prices     Unadjusted             NaN
# 1  Forestry and Logging  Current prices     Unadjusted             NaN
# 2  Forestry and Logging  Current prices     Unadjusted             NaN
# 3  Forestry and Logging  Current prices     Unadjusted             NaN
# 4  Forestry and Logging  Current prices     Unadjusted             NaN

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[4,5,6,7]
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line graph")
plt.plot(x,y)
plt.show()

# %%
x=[20,30,40,50]
y=["bananas","apples","dates","cherries"]
z=["red","yellow","green","white"]
a=[0,0,0.2,0]
plt.pie(x,labels=y,colors=z,explode=a)
plt.show()

# %%
import numpy as np
x=np.array(["a","b","c","d"])
y=np.array([2,4,3,1])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,5,6,7]
colors=["r","y","b","g","b"]
sizes=[100,200,300,40,15]
plt.scatter

# %%
plt.subplot(2,2,1)
x=[1,2,3,4]
y=[4,5,6,7]
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line graph")
plt.plot(x,y)


plt.subplot(2,2,2)
x=[20,30,40,50]
y=["bananas","apples","dates","cherries"]
c=["black","pink","yellow","blue"]
d=[0,0.2,0,0.1]
plt.pie(x,labels=y,colors=c,explode=d)


plt.subplot(2,2,3)
import numpy as np
x=np.array(["a","b","c","d"])
y=np.array([3,2.5,1,6])
z=["red","purple","green","orange"]
plt.bar(x,y,color=z)

plt.subplot(2,2,4)
x=[1,2,3,4,5]
y=[2,4,5,6,7]
colors=["r","y","b","g","b"]
sizes=[100,200,300,40,15]
plt.scatter(x,y,c=colors,s=sizes,alpha=0.9,marker="*",edgecolor="g")
plt.title("scatter",fontsize=20)
plt.xlabel("x axis",fontsize=20)
plt.ylabel("y axis",fontsize=20)
plt.show()

# %%
plt.subplot(2,2,1)
x=[1,2,3,4]
y=[4,5,6,7]
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line graph")
plt.plot(x,y)

# %%
x=[20,30,40,50]
y=["bananas","apples","dates","cherries"]
c=["black","pink","yellow","blue"]
d=[0,0.2,0,0.1]
plt.pie(x,labels=y,colors=c,explode=d)
# Out:
# ([<matplotlib.patches.Wedge at 0x783d104c4880>,
#   <matplotlib.patches.Wedge at 0x783d104c4040>,
#   <matplotlib.patches.Wedge at 0x783d104c7dc0>,
#   <matplotlib.patches.Wedge at 0x783d104c5b40>],
#  [Text(0.9910657451172095, 0.47727213291294374, 'bananas'),
#   Text(-6.085739197947509e-08, 1.2999999999999985, 'apples'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'dates'),
#   Text(0.520660660470923, -1.081162557915313, 'cherries')])

# %%
import numpy as np
x=np.array(["a","b","c","d"])
y=np.array([3,2.5,1,6])
z=["red","purple","green","orange"]
plt.bar(x,y,color=z)
# Out:
# <BarContainer object of 4 artists>

# %%
x=[1,2,3,4,5]
y=[2,4,5,6,7]
colors=["r","y","b","g","b"]
sizes=[100,200,300,40,15]
plt.scatter(x,y,c=colors,s=sizes,alpha=0.9,marker="*",edgecolor="g")
plt.title("scatter",fontsize=20)
plt.xlabel("x axis",fontsize=20)
plt.ylabel("y axis",fontsize=20)
plt.show()
